# %%
# !pip3 install -r requirements.txt
# or,

# !pip3 install black decorator numpy opencv-python matplotlib pycodestyle toml inputs ipykernel jupyter keras tensorflow tensorboard 
#tensorflow-gpu
# !pip3 install mypy-extensions pandas Pillow pynput scikit-learn scikit-image imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !python --version
# !pip --version
# !pip3 --version
# Out:
# Python 3.11.5
# pip 24.3.1 from C:\Users\PC\AppData\Roaming\Python\Python311\site-packages\pip (python 3.11)
#
# pip 24.3.1 from C:\Users\PC\AppData\Roaming\Python\Python311\site-packages\pip (python 3.11)
